# %%
import os
import pandas as pd

current_dir = os.getcwd()
data_path = current_dir + "/Data"
csv = os.listdir(data_path)
vegemite_file_path = os.path.join(data_path, "vegemite.csv")
vegemite_df = pd.read_csv(vegemite_file_path, index_col=None, header=0)
vegemite_df
# Out:
#        FFTE Feed tank level SP  FFTE Production solids SP  \
# 0                         50.0                      40.74
# 1                         50.0                      40.74
# 2                         50.0                      40.74
# 3                         50.0                      40.74
# 4                         50.0                      39.00
# ...                        ...                        ...
# 15232                     50.0                      41.50
# 15233                     50.0                      41.50
# 15234                     50.0                      41.50
# 15235                     50.0                      41.50
# 15236                     50.0                      41.50
#
#        FFTE Steam pressure SP  TFE Out flow SP  TFE Production solids SP  \
# 0                       125.0          2897.65                      69.0
# 1                       125.0          2897.65                      69.0
# 2                       125.0          2897.65                      69.0
# 3                       125.0          2897.65                      69.0
# 4                        90.0          2694.62                      64.0
# ...                       ...              ...                       ...
# 15232                   135.0          1925.30                      71.0
# 15233                   135.0          1925.30                      71.0
# 15234                   135.0          1925.30                      71.0
# 15235                   135.0          1925.30                      71.0
# 15236                   135.0          1925.30                      71.0
#
#        TFE Vacuum pressure SP  TFE Steam pressure SP  \
# 0                      -80.00                  125.0
# 1                      -79.45                  125.0
# 2                      -71.54                  125.0
# 3                      -68.44                  125.0
# 4                      -80.00                  120.0
# ...                       ...                    ...
# 15232                  -63.12                  120.0
# 15233                  -69.46                  120.0
# 15234                  -68.95                  120.0
# 15235                  -62.23                  120.0
# 15236                  -52.04                  120.0
#
#        TFE Steam temperature SP  FFTE Feed flow SP  FFTE Out steam temp SP  \
# 0                          80.0            10130.0                   49.88
# 1                          80.0            10130.0                   49.88
# 2                          80.0            10130.0                   49.88
# 3                          80.0            10130.0                   49.88
# 4                          80.0             9300.0                   49.88
# ...                         ...                ...                     ...
# 15232                      80.0             9400.0                   50.40
# 15233                      80.0             9400.0                   50.40
# 15234                      80.0             9400.0                   50.40
# 15235                      80.0             9400.0                   50.40
# 15236                      80.0             9400.0                   50.40
#
#        ...  TFE Out flow PV  TFE Product out temperature  \
# 0      ...          2577.82                          0.0
# 1      ...          1551.88                          0.0
# 2      ...          1564.85                          0.0
# 3      ...          1512.97                          0.0
# 4      ...          1795.72                          0.0
# ...    ...              ...                          ...
# 15232  ...          4532.43                          0.0
# 15233  ...          2680.29                          0.0
# 15234  ...          1859.92                          0.0
# 15235  ...          2590.14                          0.0
# 15236  ...          2590.14                          0.0
#
#        TFE Production solids PV  TFE Production solids density  \
# 0                         62.87                           1.19
# 1                         67.98                           1.19
# 2                         70.38                           1.19
# 3                         69.18                           1.19
# 4                         41.14                           0.90
# ...                         ...                            ...
# 15232                     70.84                           1.25
# 15233                     70.09                           1.25
# 15234                     70.09                           1.25
# 15235                     70.09                           1.25
# 15236                     70.09                           1.25
#
#        TFE Steam pressure PV  TFE Steam temperature  TFE Tank level  \
# 0                     125.03                  72.68           83.68
# 1                     125.03                  64.66           82.95
# 2                     124.71                  65.63           82.77
# 3                     124.71                  74.35           82.55
# 4                     119.91                  70.82           83.96
# ...                      ...                    ...             ...
# 15232                 119.91                  73.84           83.28
# 15233                 119.91                  73.46           83.72
# 15234                 119.91                  63.73           84.20
# 15235                 119.91                  71.21           86.23
# 15236                 119.91                  71.21           86.23
#
#        TFE Temperature  TFE Vacuum pressure PV  Class
# 0                 71.0                  -77.74      1
# 1                 69.0                  -79.49      1
# 2                 72.0                  -75.28      1
# 3                 76.0                  -69.65      1
# 4                 71.0                  -75.28      1
# ...                ...                     ...    ...
# 15232             74.0                  -73.50      2
# 15233             73.0                  -75.64      2
# 15234             72.0                  -76.32      2
# 15235             70.0                  -77.39      2
# 15236             70.0                  -77.03      2
#
# [15237 rows x 47 columns]

# %%
# Step 1: Data Preparation

from sklearn.model_selection import train_test_split

target_column = "Class"  # Change this if your class column has a different name

#shuffle dataset
vegemite_df = vegemite_df.sample(frac=1, random_state=42).reset_index(drop=True)

# Separate classes
class_0 = vegemite_df[vegemite_df[target_column] == 0]
class_1 = vegemite_df[vegemite_df[target_column] == 1]
class_2 = vegemite_df[vegemite_df[target_column] == 2]

# Sample 300 from each class for the test set
test_0 = class_0.sample(n=350, random_state=42)
test_1 = class_1.sample(n=350, random_state=42)
test_2 = class_2.sample(n=300, random_state=42)

# Combine balanced test dataset
test_df = pd.concat([test_0, test_1, test_2])

# Remove selected test data from the training set
train_df = vegemite_df.drop(test_df.index)

# Save the new datasets
#test_df.to_csv("balanced_test_data.csv", index=False)
#train_df.to_csv("balanced_train_data.csv", index=False)

# Print class distributions
print("New test dataset size:", len(test_df))
print(test_df[target_column].value_counts())  # Check class balance
print("\nNew train dataset size:", len(train_df))
print(test_df.shape)
print(train_df.shape)
# Out:
# New test dataset size: 1000
# 0    350
# 1    350
# 2    300
# Name: Class, dtype: int64
#
# New train dataset size: 14237
# (1000, 47)
# (14237, 47)

# %%
constant_columns = [col for col in train_df.columns if train_df[col].nunique() == 1]
constant_columns
# Out:
# ['TFE Steam temperature SP', 'TFE Product out temperature']

# %%
# remove constant columns (1.1)
light_train_df = train_df.drop(columns=constant_columns)
light_train_df.shape
# Out:
# (14237, 45)

# %%
# Print the number of unique values per column
print("Unique values per column:")
print(light_train_df.nunique())

# Print the data types of each column
print("\nData types of columns:")
print(light_train_df.dtypes)
# Out:
# Unique values per column:
# FFTE Feed tank level SP             3
# FFTE Production solids SP          12
# FFTE Steam pressure SP           2177
# TFE Out flow SP                    53
# TFE Production solids SP           96
# TFE Vacuum pressure SP           3143
# TFE Steam pressure SP              62
# FFTE Feed flow SP                  50
# FFTE Out steam temp SP             12
# Extract tank Level               5218
# Extract tank Out flow PV          634
# FFTE Discharge density             40
# FFTE Discharge solids            1140
# FFTE Feed flow rate PV            479
# FFTE Feed tank level PV          1003
# FFTE Heat temperature 1          1591
# FFTE Heat temperature 2          1275
# FFTE Heat temperature 3          1556
# FFTE Out steam temp PV            203
# FFTE Production solids PV        1517
# FFTE Pump 1                         5
# FFTE Pump 1 - 2                     4
# FFTE Pump 2                         5
# FFTE Steam pressure PV           1469
# FFTE Temperature 1 - 1            747
# FFTE Temperature 1 - 2            725
# FFTE Temperature 2 - 1            468
# FFTE Temperature 2 - 2            560
# FFTE Temperature 3 - 1            701
# FFTE Temperature 3 - 2            771
# FFTE Unk Temperature              918
# TFE Feed pump                    1403
# TFE Input flow PV                 713
# TFE Level                        1387
# TFE Motor current                1086
# TFE Motor speed                     3
# TFE Out flow PV                  1086
# TFE Production solids PV         1634
# TFE Production solids density      50
# TFE Steam pressure PV             321
# TFE Steam temperature            1299
# TFE Tank level                   4574
# TFE Temperature                    45
# TFE Vacuum pressure PV            207
# Class                               3
# dtype: int64
#
# Data types of columns:
# FFTE Feed tank level SP          float64
# FFTE Production solids SP        float64
# FFTE Steam pressure SP           float64
# TFE Out flow SP                  float64
# TFE Production solids SP         float64
# TFE Vacuum pressure SP           float64
# TFE Steam pressure SP            float64
# FFTE Feed flow SP                float64
# FFTE Out steam temp SP           float64
# Extract tank Level               float64
# Extract tank Out flow PV         float64
# FFTE Discharge density           float64
# FFTE Discharge solids            float64
# FFTE Feed flow rate PV           float64
# FFTE Feed tank level PV          float64
# FFTE Heat temperature 1          float64
# FFTE Heat temperature 2          float64
# FFTE Heat temperature 3          float64
# FFTE Out steam temp PV           float64
# FFTE Production solids PV        float64
# FFTE Pump 1                      float64
# FFTE Pump 1 - 2                  float64
# FFTE Pump 2                      float64
# FFTE Steam pressure PV           float64
# FFTE Temperature 1 - 1           float64
# FFTE Temperature 1 - 2           float64
# FFTE Temperature 2 - 1           float64
# FFTE Temperature 2 - 2           float64
# FFTE Temperature 3 - 1           float64
# FFTE Temperature 3 - 2           float64
# FFTE Unk Temperature             float64
# TFE Feed pump                    float64
# TFE Input flow PV                float64
# TFE Level                        float64
# TFE Motor current                float64
# TFE Motor speed                  float64
# TFE Out flow PV                  float64
# TFE Production solids PV         float64
# TFE Production solids density    float64
# TFE Steam pressure PV            float64
# TFE Steam temperature            float64
# TFE Tank level                   float64
# TFE Temperature                  float64
# TFE Vacuum pressure PV           float64
# Class                              int64
# dtype: object

# %%
# one hot encode categories (1.2)

from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse_output=False)
columns_to_encode = ['FFTE Pump 1', 'FFTE Pump 1 - 2', 'FFTE Pump 2', 'TFE Motor speed', 'FFTE Feed tank level SP']

# Ensure the original DataFrame index is preserved
encoded_columns = encoder.fit_transform(light_train_df[columns_to_encode])

# Step 2: Convert the encoded columns to DataFrame
encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(columns_to_encode), index=light_train_df.index)

# Step 3: Concatenate with the original DataFrame (excluding the original columns to encode)
light_train_df_encoded = pd.concat([light_train_df.drop(columns=columns_to_encode), encoded_df], axis=1)

# Step 4: Display the result
print(light_train_df_encoded.shape)
# Out:
# (14237, 55)

# %%
# Check distribution for class (1.3)
class_distribution = light_train_df_encoded['Class'].value_counts()
print(class_distribution)
# Out:
# 2    7248
# 1    4697
# 0    2292
# Name: Class, dtype: int64

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from imbalanced-learn) (1.15.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from imbalanced-learn) (1.6.1)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from imbalanced-learn) (3.5.0)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
# Successfully installed imbalanced-learn-0.13.0 sklearn-compat-0.1.3

# %%
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

X = light_train_df_encoded.drop('Class', axis=1)  # Features
y = light_train_df_encoded['Class']  # Target

# Step 1: Apply SMOTE to oversample the minority class
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Step 2: Apply Tomek Links for undersampling the majority class
tomek_links = TomekLinks()
X_final, y_final = tomek_links.fit_resample(X_resampled, y_resampled)

# Create a new balanced DataFrame
balanced_train_df = pd.DataFrame(X_final, columns=X.columns)
balanced_train_df['Class'] = y_final

# Checking the new class distribution
print(balanced_train_df['Class'].value_counts())
# Out:
# 0    7248
# 1    7142
# 2    7124
# Name: Class, dtype: int64

# %%
# explore correlations to find composite features (1.4)
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = balanced_train_df.corr()

num_features = correlation_matrix.shape[0]  # number of rows (or columns, since it's square)
fig_size = (num_features * 0.5, num_features * 0.5)  # You can adjust the multiplier (0.5) as needed

# Set up the matplotlib figure with dynamic size
plt.figure(figsize=fig_size)

# Create a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Show the plot
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
composite_train_df = balanced_train_df.copy()
composite_train_df['Feed tank level and Vacuum pressure Ratio'] = composite_train_df['FFTE Feed tank level PV'] / composite_train_df['TFE Vacuum pressure PV']
composite_train_df['Feed tank level and Production solids Ratio'] = composite_train_df['FFTE Feed tank level PV'] * composite_train_df['TFE Production solids PV']
composite_train_df['Feed tank level and TFE Out flow PV'] = composite_train_df['FFTE Feed tank level PV'] * composite_train_df['TFE Out flow PV']
composite_train_df['Feed pump and Level Ratio'] = composite_train_df['TFE Feed pump'] / composite_train_df['TFE Level']
composite_train_df['Temperature 2 - 1 and Out flow PV Ratio'] = composite_train_df['FFTE Temperature 2 - 1'] * composite_train_df['TFE Out flow PV']

# %%
# Step 2: Feature selection, Model Training and Evaluation

# alot of the features have very strong correlations with other features making them redundant, or
# there are many features that have no direct correlation with the target variable

from sklearn.feature_selection import SelectKBest, f_classif
import numpy as np

selector = SelectKBest(score_func=f_classif, k=40)
X_train_selected = selector.fit_transform(X, y)

selected_features = X.columns[selector.get_support()]

X_train_selected_df = pd.DataFrame(X_train_selected, columns=selected_features, index=X.index)

print(X_train_selected_df.shape)
# Out:
# (21514, 40)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import sys
from sklearn.preprocessing import StandardScaler

# Initialize models
models = {
    "DecisionTreeClassifier": DecisionTreeClassifier(random_state=42),
    "RandomForestClassifier": RandomForestClassifier(random_state=42),
    "SVC (Support Vector Classifier)": SVC(random_state=42),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "LogisticRegression": LogisticRegression(max_iter=100, random_state=42)
}

#scale data for SVC
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_selected_df)
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train_selected_df.columns, index=X_train_selected_df.index)

X_train, X_test, y_train, y_test = train_test_split(X_train_scaled_df, y, test_size=0.3, random_state=42)
#X_test = test_df.drop('Class', axis=1) 
#y_test = test_df['Class']  

trained_models = []

# Train and evaluate models
for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    # Print model performance
    print(f"{model_name} Accuracy: {accuracy * 100:.2f}%")
    print(f"Classification Report for {model_name}:\n{classification_report(y_test, y_pred)}")
    
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for {model_name}:\n{cm}")
    
    print("="*50)
    
    trained_models.append((model_name, model))
# Out:
# DecisionTreeClassifier Accuracy: 96.25%
# Classification Report for DecisionTreeClassifier:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2206
#            1       0.95      0.95      0.95      2118
#            2       0.97      0.97      0.97      2131
#
#     accuracy                           0.96      6455
#    macro avg       0.96      0.96      0.96      6455
# weighted avg       0.96      0.96      0.96      6455
#
# Confusion Matrix for DecisionTreeClassifier:
# [[2136   50   20]
#  [  49 2019   50]
#  [  18   55 2058]]
# ==================================================
# RandomForestClassifier Accuracy: 99.33%
# Classification Report for RandomForestClassifier:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      2206
#            1       0.99      0.99      0.99      2118
#            2       1.00      0.99      0.99      2131
#
#     accuracy                           0.99      6455
#    macro avg       0.99      0.99      0.99      6455
# weighted avg       0.99      0.99      0.99      6455
#
# Confusion Matrix for RandomForestClassifier:
# [[2189   13    4]
#  [   8 2104    6]
#  [   1   11 2119]]
# ==================================================
# SVC (Support Vector Classifier) Accuracy: 87.06%
# Classification Report for SVC (Support Vector Classifier):
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      2206
#            1       0.87      0.80      0.84      2118
#            2       0.90      0.85      0.87      2131
#
#     accuracy                           0.87      6455
#    macro avg       0.87      0.87      0.87      6455
# weighted avg       0.87      0.87      0.87      6455
#
# Confusion Matrix for SVC (Support Vector Classifier):
# [[2105   71   30]
#  [ 246 1703  169]
#  [ 135  184 1812]]
# ==================================================
# KNeighborsClassifier Accuracy: 96.20%
# Classification Report for KNeighborsClassifier:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97      2206
#            1       0.95      0.96      0.95      2118
#            2       0.98      0.94      0.96      2131
#
#     accuracy                           0.96      6455
#    macro avg       0.96      0.96      0.96      6455
# weighted avg       0.96      0.96      0.96      6455
#
# Confusion Matrix for KNeighborsClassifier:
# [[2174   24    8]
#  [  51 2025   42]
#  [  35   85 2011]]
# ==================================================
# LogisticRegression Accuracy: 53.63%
# Classification Report for LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.54      0.67      0.60      2206
#            1       0.48      0.34      0.40      2118
#            2       0.57      0.60      0.58      2131
#
#     accuracy                           0.54      6455
#    macro avg       0.53      0.53      0.53      6455
# weighted avg       0.53      0.54      0.53      6455
#
# Confusion Matrix for LogisticRegression:
# [[1479  329  398]
#  [ 848  710  560]
#  [ 427  431 1273]]
# ==================================================
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# save best model
import joblib

# save the random forest model
joblib.dump(trained_models[1][1], 'best_model.pkl')
# Out:
# ['best_model.pkl']

# %%
# Step 3: ML to AI

best_model = joblib.load('best_model.pkl')
best_model
print(test_df.shape)
# Out:
# (1000, 47)

# %%
light_test_df = test_df.drop(columns=constant_columns)
light_test_df.shape
# Out:
# (1000, 45)

# %%
y_test = light_test_df['Class']

encoder = OneHotEncoder(sparse_output=False)
columns_to_encode = ['FFTE Pump 1', 'FFTE Pump 1 - 2', 'FFTE Pump 2', 'TFE Motor speed', 'FFTE Feed tank level SP']

encoded_columns = encoder.fit_transform(light_test_df[columns_to_encode])

test_encoded_df = pd.DataFrame(encoded_columns, columns=encoder.get_feature_names_out(columns_to_encode), index=light_test_df.index)

test_encoded_df = pd.concat([light_test_df.drop(columns=columns_to_encode), test_encoded_df], axis=1)
test_encoded_df.shape
# Out:
# (1000, 56)

# %%
composite_test_df = test_encoded_df.copy()
composite_test_df['Feed tank level and Vacuum pressure Ratio'] = composite_test_df['FFTE Feed tank level PV'] / composite_test_df['TFE Vacuum pressure PV']
composite_test_df['Feed tank level and Production solids Ratio'] = composite_test_df['FFTE Feed tank level PV'] * composite_test_df['TFE Production solids PV']
composite_test_df['Feed tank level and TFE Out flow PV'] = composite_test_df['FFTE Feed tank level PV'] * composite_test_df['TFE Out flow PV']
composite_test_df['Feed pump and Level Ratio'] = composite_test_df['TFE Feed pump'] / composite_test_df['TFE Level']
composite_test_df['Temperature 2 - 1 and Out flow PV Ratio'] = composite_test_df['FFTE Temperature 2 - 1'] * composite_test_df['TFE Out flow PV']
composite_test_df.head()
# Out:
#        FFTE Production solids SP  FFTE Steam pressure SP  TFE Out flow SP  \
# 9524                        40.5                  122.47          2296.30
# 13386                       43.0                  126.72          2255.81
# 13801                       42.0                  126.51          2214.29
# 5773                        42.0                  110.00          2214.29
# 2294                        43.0                  121.03          2609.30
#
#        TFE Production solids SP  TFE Vacuum pressure SP  \
# 9524                       62.0                  -80.00
# 13386                      68.0                  -80.00
# 13801                      71.0                  -79.38
# 5773                       63.0                  -44.63
# 2294                       71.0                  -71.04
#
#        TFE Steam pressure SP  FFTE Feed flow SP  FFTE Out steam temp SP  \
# 9524                   125.0             9300.0                   50.00
# 13386                  120.0            10000.0                   50.10
# 13801                  120.0             9300.0                   50.33
# 5773                   125.0             9300.0                   50.00
# 2294                   120.0            10200.0                   50.33
#
#        Extract tank Level  Extract tank Out flow PV  ...  TFE Motor speed_0.0  \
# 9524                65.46                      1.46  ...                  0.0
# 13386               63.96                      1.56  ...                  0.0
# 13801               68.02                     20.97  ...                  0.0
# 5773                69.65                     12.62  ...                  0.0
# 2294                32.36                      6.17  ...                  0.0
#
#        TFE Motor speed_20.0  TFE Motor speed_80.0  \
# 9524                    0.0                   1.0
# 13386                   0.0                   1.0
# 13801                   0.0                   1.0
# 5773                    0.0                   1.0
# 2294                    0.0                   1.0
#
#        FFTE Feed tank level SP_25.0  FFTE Feed tank level SP_50.0  \
# 9524                            0.0                           1.0
# 13386                           0.0                           1.0
# 13801                           0.0                           1.0
# 5773                            0.0                           1.0
# 2294                            0.0                           1.0
#
#        Feed tank level and Vacuum pressure Ratio  \
# 9524                                   -0.928835
# 13386                                  -0.720011
# 13801                                  -0.628218
# 5773                                   -0.690225
# 2294                                   -0.752141
#
#        Feed tank level and Production solids Ratio  \
# 9524                                     3135.0975
# 13386                                    3676.3962
# 13801                                    3181.1766
# 5773                                     3216.8380
# 2294                                     3403.9480
#
#        Feed tank level and TFE Out flow PV  Feed pump and Level Ratio  \
# 9524                            74755.9200                   0.413493
# 13386                          149088.8338                   0.449415
# 13801                          127668.0006                   0.444840
# 5773                            86983.6054                   0.604230
# 2294                            81728.2012                   0.493746
#
#        Temperature 2 - 1 and Out flow PV Ratio
# 9524                                97205.0112
# 13386                              185963.7467
# 13801                              161754.2430
# 5773                               116399.0106
# 2294                               105736.5872
#
# [5 rows x 61 columns]

# %%
composite_test_df_y = composite_test_df['Class'] 
composite_test_df_X = composite_test_df.drop('Class', axis=1) 

common_columns = X_train_selected_df.columns.intersection(composite_test_df_X.columns)
X_test_filtered = composite_test_df_X[common_columns]

# %%
X_test_scaled = scaler.transform(X_test_filtered)

# %%
predictions = best_model.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy * 100:.2f}%')
print(f"Classification Report for best model:\n{classification_report(y_test, predictions)}")
# Out:
# Accuracy: 99.90%
# Classification Report for best model:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       350
#            1       1.00      1.00      1.00       350
#            2       1.00      1.00      1.00       300
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000

# %%
models = {
    "DecisionTreeClassifier": DecisionTreeClassifier(random_state=42),
    "SVC (Support Vector Classifier)": SVC(random_state=42),
    "KNeighborsClassifier": KNeighborsClassifier(),
    "LogisticRegression": LogisticRegression(max_iter=100, random_state=42)
}

X_train, X_test, y_train, y_test = train_test_split(X_test_scaled, y_test, test_size=0.3, random_state=42)

for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions
    y_pred = model.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    # Print model performance
    print(f"{model_name} Accuracy: {accuracy * 100:.2f}%")
    print(f"Classification Report for {model_name}:\n{classification_report(y_test, y_pred)}")
    
    cm = confusion_matrix(y_test, y_pred)
    print(f"Confusion Matrix for {model_name}:\n{cm}")
    
    print("="*50)
# Out:
# DecisionTreeClassifier Accuracy: 70.00%
# Classification Report for DecisionTreeClassifier:
#               precision    recall  f1-score   support
#
#            0       0.76      0.80      0.78       110
#            1       0.70      0.68      0.69       103
#            2       0.62      0.60      0.61        87
#
#     accuracy                           0.70       300
#    macro avg       0.69      0.69      0.69       300
# weighted avg       0.70      0.70      0.70       300
#
# Confusion Matrix for DecisionTreeClassifier:
# [[88  9 13]
#  [14 70 19]
#  [14 21 52]]
# ==================================================
# SVC (Support Vector Classifier) Accuracy: 58.33%
# Classification Report for SVC (Support Vector Classifier):
#               precision    recall  f1-score   support
#
#            0       0.60      0.85      0.70       110
#            1       0.55      0.36      0.44       103
#            2       0.58      0.52      0.55        87
#
#     accuracy                           0.58       300
#    macro avg       0.58      0.57      0.56       300
# weighted avg       0.58      0.58      0.56       300
#
# Confusion Matrix for SVC (Support Vector Classifier):
# [[93 12  5]
#  [39 37 27]
#  [24 18 45]]
# ==================================================
# KNeighborsClassifier Accuracy: 64.67%
# Classification Report for KNeighborsClassifier:
#               precision    recall  f1-score   support
#
#            0       0.62      0.90      0.73       110
#            1       0.69      0.53      0.60       103
#            2       0.67      0.46      0.54        87
#
#     accuracy                           0.65       300
#    macro avg       0.66      0.63      0.63       300
# weighted avg       0.66      0.65      0.63       300
#
# Confusion Matrix for KNeighborsClassifier:
# [[99  8  3]
#  [31 55 17]
#  [30 17 40]]
# ==================================================
# LogisticRegression Accuracy: 46.67%
# Classification Report for LogisticRegression:
#               precision    recall  f1-score   support
#
#            0       0.50      0.55      0.52       110
#            1       0.41      0.38      0.40       103
#            2       0.48      0.47      0.48        87
#
#     accuracy                           0.47       300
#    macro avg       0.46      0.47      0.46       300
# weighted avg       0.46      0.47      0.46       300
#
# Confusion Matrix for LogisticRegression:
# [[60 32 18]
#  [38 39 26]
#  [23 23 41]]
# ==================================================

# %%
# Step 4: Develop rules from the ML model

columns_to_keep = [col for col in X_train_selected_df.columns if col.endswith('SP')]
X_train_only_sp = X_train_scaled_df[columns_to_keep]
# Out:
#        FFTE Production solids SP  FFTE Steam pressure SP  TFE Out flow SP  \
# 0                       1.097681                0.243686         0.524690
# 1                      -0.249887               -1.114269        -0.951111
# 2                      -1.148266               -0.188391        -0.741848
# 3                      -1.148266                0.428862        -1.095420
# 4                       1.097681               -1.731521         1.270283
# ...                          ...                     ...              ...
# 21509                  -0.249887                1.046114        -0.951111
# 21510                   1.097681               -1.183260         1.513935
# 21511                   1.097681                0.794532         0.533625
# 21512                  -0.249887                0.692530        -0.951111
# 21513                  -2.495835                0.473660        -1.366248
#
#        TFE Production solids SP  TFE Vacuum pressure SP  FFTE Feed flow SP  \
# 0                      0.452769                0.947281           0.244528
# 1                      0.172887               -1.055552          -0.427784
# 2                     -1.611359                1.464943          -0.554776
# 3                      0.032946               -0.779767          -0.427784
# 4                     -4.025339                1.581737           0.117536
# ...                         ...                     ...                ...
# 21509                 -4.025339                1.204981           3.008477
# 21510                  0.756172                1.324306           0.117536
# 21511                  0.717362               -1.013228           0.169827
# 21512                  0.102917                0.150304          -0.427784
# 21513                  0.102917               -1.055552          -0.427784
#
#        FFTE Out steam temp SP
# 0                    0.211172
# 1                    0.149180
# 2                    0.149180
# 3                    0.149180
# 4                   -0.222773
# ...                       ...
# 21509                0.149180
# 21510               -4.650038
# 21511                0.317927
# 21512                0.149180
# 21513                0.149180
#
# [21514 rows x 7 columns]

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train_only_sp, y)

tree_rules = export_text(clf, feature_names=list(X_train_only_sp.columns))
print(tree_rules)
# Out:
# |--- FFTE Feed flow SP <= 0.17
# |   |--- FFTE Feed flow SP <= -0.56
# |   |   |--- FFTE Production solids SP <= -0.59
# |   |   |   |--- FFTE Production solids SP <= -1.82
# |   |   |   |   |--- FFTE Steam pressure SP <= -0.34
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Steam pressure SP >  -0.34
# |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.98
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.16
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.57
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= -0.39
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  -0.39
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= -0.28
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  -0.28
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.57
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.16
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.12
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.12
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.98
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.71
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.13
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.57
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.57
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.13
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.71
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- FFTE Production solids SP >  -1.82
# |   |   |   |   |--- FFTE Steam pressure SP <= -0.92
# |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.13
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.57
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.89
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= -0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  -0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.89
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.57
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.13
# |   |   |   |   |   |   |--- TFE Production solids SP <= -0.75
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Production solids SP >  -0.75
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.72
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.72
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Steam pressure SP >  -0.92
# |   |   |   |   |   |--- FFTE Feed flow SP <= -0.73
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Feed flow SP >  -0.73
# |   |   |   |   |   |   |--- TFE Out flow SP <= 0.47
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.56
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.95
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.96
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.96
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= -0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  -0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.95
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.56
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Out flow SP >  0.47
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- FFTE Production solids SP >  -0.59
# |   |   |   |--- TFE Out flow SP <= -0.60
# |   |   |   |   |--- TFE Out flow SP <= -1.27
# |   |   |   |   |   |--- FFTE Feed flow SP <= -0.61
# |   |   |   |   |   |   |--- TFE Production solids SP <= 0.10
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Production solids SP >  0.10
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.42
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.15
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.16
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.16
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.42
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.87
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.99
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.99
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.87
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.46
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.46
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Feed flow SP >  -0.61
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TFE Out flow SP >  -1.27
# |   |   |   |   |   |--- TFE Production solids SP <= 0.52
# |   |   |   |   |   |   |--- FFTE Feed flow SP <= -3.77
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Feed flow SP >  -3.77
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.01
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.58
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.58
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.01
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Production solids SP >  0.52
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.05
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.85
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.85
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.12
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.16
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.16
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.12
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.05
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- TFE Out flow SP >  -0.60
# |   |   |   |   |--- TFE Production solids SP <= 0.58
# |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.06
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 1.11
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.73
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.73
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.73
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.73
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  1.11
# |   |   |   |   |   |   |   |--- FFTE Production solids SP <= -0.08
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Production solids SP >  -0.08
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.24
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.61
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.24
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.06
# |   |   |   |   |   |   |--- TFE Out flow SP <= -0.59
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Out flow SP >  -0.59
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.04
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.18
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.27
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.18
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.42
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.04
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TFE Production solids SP >  0.58
# |   |   |   |   |   |--- FFTE Production solids SP <= 0.10
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Production solids SP >  0.10
# |   |   |   |   |   |   |--- TFE Production solids SP <= 0.66
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.18
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.18
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.81
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.81
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Production solids SP >  0.66
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.18
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.68
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.65
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.68
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.18
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.18
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.18
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |--- FFTE Feed flow SP >  -0.56
# |   |   |--- FFTE Steam pressure SP <= 0.65
# |   |   |   |--- FFTE Out steam temp SP <= -0.22
# |   |   |   |   |--- FFTE Production solids SP <= -1.11
# |   |   |   |   |   |--- FFTE Feed flow SP <= -0.47
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.02
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.04
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.77
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.77
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.04
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.04
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.04
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.02
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.24
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.24
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.77
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.77
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- FFTE Feed flow SP >  -0.47
# |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.29
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.43
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.43
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.46
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.92
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.92
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 1.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  1.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.46
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.29
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.70
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.99
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.24
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.24
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.99
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.70
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.27
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.27
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Production solids SP >  -1.11
# |   |   |   |   |   |--- FFTE Production solids SP <= -0.25
# |   |   |   |   |   |   |--- TFE Out flow SP <= -0.77
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Out flow SP >  -0.77
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.45
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= -1.67
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  -1.67
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.45
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.38
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.38
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.61
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.61
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- FFTE Production solids SP >  -0.25
# |   |   |   |   |   |   |--- TFE Production solids SP <= 0.87
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.38
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.89
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.89
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.43
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.43
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.38
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Production solids SP >  0.87
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.57
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.09
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 1.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  1.55
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.09
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 1.46
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  1.46
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.57
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 0.04
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  0.04
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.91
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 1.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  1.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.91
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- FFTE Out steam temp SP >  -0.22
# |   |   |   |   |--- FFTE Production solids SP <= -2.46
# |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.09
# |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.50
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= -0.29
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  -0.29
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.16
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.16
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.65
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.65
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- FFTE Out steam temp SP >  0.09
# |   |   |   |   |   |   |--- TFE Production solids SP <= 0.10
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.44
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.44
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.44
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.44
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.27
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.27
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.62
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.62
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- TFE Production solids SP >  0.10
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.20
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.51
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.20
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.03
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.65
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.03
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.30
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.30
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Production solids SP >  -2.46
# |   |   |   |   |   |--- TFE Out flow SP <= -0.49
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.12
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.80
# |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= -0.47
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.45
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -1.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -1.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.45
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.37
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  -0.47
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.13
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.13
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.80
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.13
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.69
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.13
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -1.27
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.73
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -1.27
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.12
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.96
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.38
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -1.28
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -1.28
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.38
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.67
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.67
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -1.01
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.96
# |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 0.09
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.21
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.21
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  0.09
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP <= 0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Production solids SP >  0.42
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Out flow SP >  -0.49
# |   |   |   |   |   |   |--- FFTE Production solids SP <= -0.25
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.35
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.26
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.41
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.41
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.26
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.71
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.35
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.72
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= -0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  -0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.72
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.69
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Production solids SP >  -0.25
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.18
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.71
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -2.62
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.77
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -2.62
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.71
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1.11
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1.11
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.18
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 1.25
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.73
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1.16
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.73
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  1.25
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 1.18
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  1.18
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 1.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  1.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- FFTE Steam pressure SP >  0.65
# |   |   |   |--- FFTE Out steam temp SP <= 0.37
# |   |   |   |   |--- FFTE Out steam temp SP <= 0.21
# |   |   |   |   |   |--- FFTE Feed flow SP <= -0.35
# |   |   |   |   |   |   |--- TFE Out flow SP <= 0.72
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= -1.45
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.18
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -1.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -1.75
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.06
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.18
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.47
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  -1.45
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.74
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.35
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.35
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.74
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 1.34
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  1.34
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  -0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- TFE Out flow SP >  0.72
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.17
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.17
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.77
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.77
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- FFTE Feed flow SP >  -0.35
# |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.12
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= -0.68
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  -0.68
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 1.82
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  1.82
# |   |   |   |   |   |   |   |   |   |--- class: 1
# ...
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.08
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= -4.10
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  -4.10
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- TFE Production solids SP >  0.31
# |   |   |   |   |--- TFE Production solids SP <= 1.08
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.12
# |   |   |   |   |   |   |--- TFE Production solids SP <= 0.94
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.45
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1.41
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.32
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.32
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1.41
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 1.40
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  0.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  1.40
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.45
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.83
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.83
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -2.04
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -2.04
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |--- TFE Production solids SP >  0.94
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1.53
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.94
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.94
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 1.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  1.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  1.53
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -2.22
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -2.22
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -2.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -2.18
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Steam pressure SP >  0.12
# |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 1.36
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.55
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.21
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.21
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.55
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.69
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 1.04
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  1.04
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- FFTE Feed flow SP >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.69
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.46
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1.41
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.46
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Steam pressure SP >  1.36
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- TFE Production solids SP >  1.08
# |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.27
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.27
# |   |   |   |   |   |   |--- TFE Production solids SP <= 1.38
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.09
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.09
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= -0.08
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  -0.08
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.64
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  0.64
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Production solids SP >  1.38
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.11
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.11
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- TFE Production solids SP >  1.50
# |   |   |   |--- TFE Vacuum pressure SP <= 1.17
# |   |   |   |   |--- FFTE Steam pressure SP <= 1.94
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- FFTE Steam pressure SP >  1.94
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- TFE Vacuum pressure SP >  1.17
# |   |   |   |   |--- class: 0
# |   |--- FFTE Out steam temp SP >  0.21
# |   |   |--- FFTE Out steam temp SP <= 0.72
# |   |   |   |--- FFTE Steam pressure SP <= 0.60
# |   |   |   |   |--- FFTE Out steam temp SP <= 0.35
# |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.18
# |   |   |   |   |   |   |--- TFE Out flow SP <= 0.92
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.14
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.14
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.17
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.17
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Out flow SP >  0.92
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.09
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.09
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Steam pressure SP >  0.18
# |   |   |   |   |   |   |--- TFE Out flow SP <= 0.76
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.59
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.59
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.29
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.29
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Out flow SP >  0.76
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Out steam temp SP >  0.35
# |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.39
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- FFTE Out steam temp SP >  0.39
# |   |   |   |   |   |   |--- TFE Out flow SP <= 1.12
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Out flow SP >  1.12
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.36
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP <= 1.15
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Out flow SP >  1.15
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.36
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- FFTE Steam pressure SP >  0.60
# |   |   |   |   |--- FFTE Out steam temp SP <= 0.49
# |   |   |   |   |   |--- TFE Production solids SP <= -4.20
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Production solids SP >  -4.20
# |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 0.25
# |   |   |   |   |   |   |   |--- TFE Out flow SP <= 0.79
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Out flow SP >  0.79
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- FFTE Out steam temp SP >  0.25
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Out steam temp SP >  0.49
# |   |   |   |   |   |--- TFE Out flow SP <= 1.10
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- TFE Out flow SP >  1.10
# |   |   |   |   |   |   |--- FFTE Production solids SP <= 0.42
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- FFTE Production solids SP >  0.42
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |--- FFTE Out steam temp SP >  0.72
# |   |   |   |--- FFTE Feed flow SP <= 0.24
# |   |   |   |   |--- FFTE Steam pressure SP <= 0.58
# |   |   |   |   |   |--- TFE Out flow SP <= 1.08
# |   |   |   |   |   |   |--- TFE Production solids SP <= -0.41
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Production solids SP >  -0.41
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- TFE Out flow SP >  1.08
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 2.23
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  2.23
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.27
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.27
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- FFTE Steam pressure SP >  0.58
# |   |   |   |   |   |--- TFE Out flow SP <= 1.08
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -1.05
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.39
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.39
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -1.05
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- TFE Out flow SP >  1.08
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- FFTE Feed flow SP >  0.24
# |   |   |   |   |--- TFE Out flow SP <= 0.80
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- TFE Out flow SP >  0.80
# |   |   |   |   |   |--- TFE Production solids SP <= 1.22
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.37
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.43
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP <= 0.95
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Steam pressure SP >  0.95
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.69
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.69
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= -0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.43
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP <= 0.73
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- TFE Production solids SP >  0.73
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  -0.37
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 2.21
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  2.21
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP <= 1.57
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- FFTE Out steam temp SP >  1.57
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- TFE Production solids SP >  1.22
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP <= 2.23
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- TFE Vacuum pressure SP >  2.23
# |   |   |   |   |   |   |   |--- TFE Production solids SP <= 1.68
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- TFE Production solids SP >  1.68
# |   |   |   |   |   |   |   |   |--- class: 2
